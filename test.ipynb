# %%
import pandas as pd

pd.read_csv("results.csv")[10:50]
# Out:
#     ln  col  block                                              token  \
# 10   3   35      1                                                  [
# 11   3   36      1                                                  ]
# 12   3   38      1                                               args
# 13   3   42      1                                                  )
# 14   3   44      2                                                  {
# 15   4    9      2  // Comment: this is a comment which will be ig...
# 16   6    9      2                                        // Keywords
# 17   7    9      2                                                int
# 18   7   13      2                                              count
# 19   7   19      2                                                  =
# 20   7   21      2                                                  0
# 21   7   22      2                                                  ;
# ...
